# %%
# %pylab inline
rcParams.update({"font.size":25})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import os
os.chdir("/Users/cham/PycharmProjects/spectroscopy/stellar_parameters/")
print(os.getcwd())
# Out:
# /Users/cham/PycharmProjects/spectroscopy/stellar_parameters

# %%
"""
https://phoenix.astro.physik.uni-goettingen.de/
"""
from astropy.io import fits
flux_hi = fits.getdata("demo_ccf/lte05800-4.50-0.0.PHOENIX-ACES-AGSS-COND-2011-HiRes.fits")
wave_hi = fits.getdata("demo_ccf/WAVE_PHOENIX-ACES-AGSS-COND-2011.fits")
figure(figsize=(15, 7))
plot(wave_hi, flux_hi)
xlim(3000, 25000)
# Out:
# (3000.0, 25000.0)

# %%
xx = np.arange(10)
figure(figsize=(15,7))
for i in range(3):
    yy = np.ones_like(xx) * i
    plot(xx-i, yy,"s", ms=20, mec="k")
ylim(-1, 4)
# Out:
# (-1.0, 4.0)

# %%
import joblib
r = joblib.load("/Users/cham/projects/speclib/ferre/R7500_regli.dump")

# %%
from laspec.normalization import normalize_spectrum_spline
def plot_star(ax, p, **kwargs):
    ax.plot(r.wave, flux_norm)
    return

# %%
rcParams["font.size"]=20
fig, axs = plt.subplots(1, 2, figsize=(15, 7), sharex=False, sharey=True)
lw = 3
plot_teff=10000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
axs[0].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
axs[1].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)

plot_teff=8000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
axs[0].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
axs[1].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)

plot_teff=6000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
axs[0].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
axs[1].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)

plot_teff=4000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
axs[0].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
axs[1].plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)

plot_teff=5800
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
axs[0].plot(r.wave, flux_norm, label="obs", c="k", lw=lw)
axs[1].plot(r.wave, flux_norm, label="obs", c="k", lw=lw)

axs[0].grid(True)
axs[1].grid(True)
axs[1].legend()
axs[0].set_xlim(5160, 5190)
axs[1].set_xlim(6550, 6580)
axs[0].set_ylim(0, 1.5)
axs[0].set_xlabel("$\lambda$ [$\mathrm{\AA}]$")
axs[1].set_xlabel("$\lambda$ [$\mathrm{\AA}]$")
axs[0].set_ylabel("Normalized flux")
axs[0].set_title("Mg I")
axs[1].set_title("H$\\alpha$")
fig.tight_layout()

# %%
rcParams["font.size"]=25
fig, ax = plt.subplots(1, 1, figsize=(10, 7), sharex=False, sharey=True)
lw = 3
plot_teff=10000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
plot_teff=8000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
plot_teff=6000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
plot_teff=4000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)

ax.set_xlim(6550, 6578)
# Out:
# (6550.0, 6578.0)

# %%
rcParams["font.size"]=25
fig, ax = plt.subplots(1, 1, figsize=(10, 7), sharex=False, sharey=True)
lw = 3
plot_teff=6000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw)
plot_teff=5800
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, label="{:d} K".format(plot_teff), lw=lw,c="k")
ax.set_xlim(6550, 6578)
# Out:
# (6550.0, 6578.0)

# %%
rcParams["font.size"]=25
fig, ax = plt.subplots(1, 1, figsize=(20, 7), sharex=False, sharey=True)
lw = 5
plot_teff=5800
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm, "-", label="model".format(plot_teff), lw=lw,c="gray")

plot_teff=5800
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0], rv=100), niter=3)
ax.plot(r.wave, flux_norm, "-", label="obs", lw=lw,c="k")

ax.vlines([5185.1, 5186.8], -.1, 1.1, linestyle="--", lw=lw, color="skyblue")
ax.text(5186, 1., "$\Delta \lambda$", va="center", ha="center", fontsize=30, color="k")

xx = np.linspace(5170, 5200, 1000)
yy = 1-.65*np.exp(-(xx-5186.8)**2)
ax.plot(xx, yy, lw=lw, c="r", label="line fitting")

ax.grid(True)
ax.set_xlim(5165, 5200)
ax.set_ylim(-.1, 1.1)
legend()
ax.set_xlabel("$\lambda$ [$\mathrm{\AA}$]")
ax.set_ylabel("Normalized Flux")
# Out:
# Text(0, 0.5, 'Normalized Flux')

# %%
rcParams["font.size"]=25
fig, ax = plt.subplots(1, 1, figsize=(20, 10), sharex=False, sharey=True)
lw = 5

ofst = 4
plot_teff=5000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm+ofst, "-", label="{} K".format(plot_teff), lw=lw,)
xx = np.linspace(5160, 5200, 1000)
yy = 1-.72*np.exp(-(xx-5185.1)**2/4)+ofst
ax.fill_between(xx, yy, 1+ofst, color="gray", label="EW",alpha=0.7)

ofst = 3
plot_teff=6000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm+ofst, "-", label="{} K".format(plot_teff), lw=lw,)
xx = np.linspace(5160, 5200, 1000)
yy = 1-.63*np.exp(-(xx-5185.1)**2)+ofst
ax.fill_between(xx, yy, 1+ofst, color="gray")

ofst = 2
plot_teff=7000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm+ofst, "-", label="{} K".format(plot_teff), lw=lw,)
xx = np.linspace(5160, 5200, 1000)
yy = 1-.4*np.exp(-(xx-5185.1)**2*1.5)+ofst
ax.fill_between(xx, yy, 1+ofst, color="gray")

ofst = 1
plot_teff=8000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm+ofst, "-", label="{} K".format(plot_teff), lw=lw,)
xx = np.linspace(5160, 5200, 1000)
yy = 1-.25*np.exp(-(xx-5185.1)**2*2.5)+ofst
ax.fill_between(xx, yy, 1+ofst, color="gray")

ofst = 0
plot_teff=9000
flux_norm, flux_cont = normalize_spectrum_spline(r.wave, r.predict_spectrum([plot_teff, 4.5, 0, 0]), niter=3)
ax.plot(r.wave, flux_norm+ofst, "-", label="{} K".format(plot_teff), lw=lw,)
xx = np.linspace(5160, 5200, 1000)
yy = 1-.18*np.exp(-(xx-5185.1)**2*4)+ofst
ax.fill_between(xx, yy, 1+ofst, color="gray")
ax.grid(True)
ax.set_xlim(5165, 5200)
ax.set_ylim(-.1, 5.1)

ax.legend(loc="upper right")
ax.set_xlabel("$\lambda$ [$\mathrm{\AA}$]")
ax.set_ylabel("Normalized Flux")
# Out:
# /Users/cham/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:216: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/cham/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:185: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# /Users/cham/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /Users/cham/anaconda3/lib/python3.8/site-packages/laspec/normalization.py:233: RuntimeWarning: invalid value encountered in greater
#   ind_good = ind_good & (res1 > lu[0]) & (res1 < lu[1])
# /Users/cham/anaconda3/lib/python3.8/site-packages/laspec/normalization.py:233: RuntimeWarning: invalid value encountered in less
#   ind_good = ind_good & (res1 > lu[0]) & (res1 < lu[1])
# Text(0, 0.5, 'Normalized Flux')

# %%
def gc(x):
    return (x-10000)**2

rcParams["font.size"]=25
fig, ax = plt.subplots(1, 1, figsize=(10, 8), sharex=False, sharey=True)
lw = 5
x = np.arange(5000, 10000, 1000)
xx = np.arange(4000, 10000, 1)
ax.plot(xx, gc(xx),'k-', lw=5)
ax.plot(x, gc(x),'s',mfc="gray", ms=20, mec="k")

ax.set_xlabel("$T_\mathrm{eff}$ [K]")
ax.set_ylabel("Equivalent Width")
ax.set_yticks([])
# Out:
# []

# %%
def f(x):
    x = np.array(x)
    return np.exp(-0.5*(x-5900)**2/1000**2)
figure(figsize=(10, 7))
x = [4000, 6000, 8000, 10000]
plot(x, f(x),"s",  c='darkcyan', ms=15, mec="k")
xx = np.linspace(4000, 10000, 100)
plot(xx, f(xx), 'k-', lw=3)
ylabel("Likelihood / Similarity")
xlabel("$T_\mathrm{eff}$ [K]")
grid(True)
fig.tight_layout()

# %%
x = np.linspace(-1, 1, 100)
y = np.linspace(-1, 1, 100)
xx, yy = np.meshgrid(x, y)

zz = xx**2+yy**2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(12, 10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(xx, yy, zz,cmap=cm.plasma)
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.set_zticklabels([])
ax.set_xlabel("$\\theta_2$")
ax.set_ylabel("$\\theta_1$")
ax.set_zlabel("Negative Likelihood")
# Out:
# Text(0.5, 0, 'Negative Likelihood')

# %%
rcParams["font.size"]=25
fig, axs = plt.subplots(1, 2, figsize=(15, 7), sharex=False, sharey=True)

def sigmoid(x):
    return 1/(1+np.exp(-x))
def g(x):
    return np.sin(x*np.pi)


x = np.linspace(-1, 1, 30)
y = g(x)
axs[0].plot(x, y, "k-", lw=3, label="Truth")
axs[0].plot(x, y, "s", ms=10, label="Grid",mec="k")

x = np.linspace(-1, 1, 100)
y = g(x)
axs[1].plot(x, y, "k-", lw=3, label="Truth")
xn = np.random.uniform(-1, 1, 100)
xn = np.sort(xn)
yn = np.random.normal(0,.2, 100)+g(xn)
axs[1].plot(xn, yn, 'o', color="darkcyan", label="Observation",ms=10,mec="k")


xx = np.linspace(-1, 1, 1000)
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
svr = SVR(C=10, epsilon=0.05)
svr.fit(xn.reshape(-1,1), yn)
axs[1].plot(xx, svr.predict(xx.reshape(-1,1)), "-", color="m", lw=3,label="SVR")

nn = MLPRegressor(activation="logistic", hidden_layer_sizes=(100,), learning_rate_init=0.01, max_iter=10000,solver="lbfgs")
nn.fit(xn.reshape(-1,1), yn)
axs[1].plot(xx, nn.predict(xx.reshape(-1,1)), "-", color="lightcoral", lw=3,label="NN")


for i in range(2):
    axs[i].legend(loc="upper left")
    axs[i].set_xlim(-1,1)
    axs[i].set_ylim(-1.3,1.3)
    axs[i].set_xlabel("a specific parameter $\\theta$")
    axs[i].set_ylabel("Normalized Flux")
    axs[i].set_xticklabels([])
    axs[i].set_yticklabels([])
axs[0].set_title("Case A. Synthetic spectra")
axs[1].set_title("Case B. Empirical spectra")
fig.tight_layout()

# %%
rcParams["font.size"]=25
fig, axs = plt.subplots(1,2, figsize=(12, 6),)

n=100
xx = np.random.randn(n)
axs[0].plot(xx+np.random.normal(0, 0.03, n),xx+np.random.normal(0, 0.03, n),'o',color="darkcyan",mec="k",ms=10,alpha=0.7)
axs[0].set_xticks([])
axs[0].set_xticklabels([])
axs[0].set_yticks([])
axs[0].set_yticklabels([])
axs[0].set_xlabel("$\\theta_1$ (e.g., [Mg/H])")
axs[0].set_ylabel("$\\theta_2$ (e.g., [Ca/H])")

xx = np.linspace(-5, 15, 500)
axs[1].plot(xx,1-1*(np.exp(-(xx-3)**2)+0.5*np.exp(-(xx-8)**2)),lw=3)
axs[1].plot(xx,2-0.5*(np.exp(-(xx-3)**2)+0.5*np.exp(-(xx-8)**2)),lw=3)
axs[1].vlines([3,8], -1, 3, linestyle="--")
axs[1].text(3, 1, "Mg")
axs[1].text(8, 1, "Ca")
axs[1].set_xlim(-5, 15)
axs[1].set_ylim(-1, 3)
axs[1].set_xticks([])
axs[1].set_xticklabels([])
axs[1].set_yticks([])
axs[1].set_yticklabels([])
axs[1].set_xlabel("$\\lambda$ [$\mathrm{\AA}$]")
axs[1].set_ylabel("Flux")
fig.tight_layout()
#%%
ax.set_xticks([])
ax.set_xticklabels([])
ax.set_xlabel("$\\theta_1$")
ax.set_yticks([])
ax.set_yticklabels([])
ax.set_ylabel("$\\theta_2$")
# Out:
# Text(3.200000000000003, 0.5, '$\\theta_2$')
